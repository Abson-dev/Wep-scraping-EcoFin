# %% [markdown]
# # 📰 Analyse des actualités agricoles de l'Agence Ecofin
#
# Ce notebook a pour objectif de scraper des articles liés à la régulation des exportations agricoles dans les pays d’Afrique de l’Ouest, extraits du site [agenceecofin.com](https://www.agenceecofin.com/actualites-agro), puis d'extraire les données pertinentes et les sauvegarder dans un fichier Excel.

# %%
#!python -m spacy download fr_core_news_sm

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
import spacy
from tqdm import tqdm

# %%
# Charger le modèle de langue français de spaCy
nlp = spacy.load("fr_core_news_sm")

# %%
# Initialisation des variables
mois_francais = {
    'janvier': '01', 'février': '02', 'fevrier': '02', 'mars': '03',
    'avril': '04', 'mai': '05', 'juin': '06',
    'juillet': '07', 'août': '08', 'aout': '08', 'septembre': '09',
    'octobre': '10', 'novembre': '11', 'décembre': '12', 'decembre': '12'
}

# Liste complète des pays africains
countries = [
    "Algérie", "Angola", "Bénin", "Botswana", "Burkina Faso", "Burundi", "Cap-Vert", "Cameroun",
    "République centrafricaine", "Tchad", "Comores", "Congo", "République démocratique du Congo",
    "Côte d'Ivoire", "Djibouti", "Égypte", "Guinée équatoriale", "Érythrée", "Eswatini", "Éthiopie",
    "Gabon", "Gambie", "Ghana", "Guinée", "Guinée-Bissau", "Kenya", "Lesotho", "Libéria", "Libye",
    "Madagascar", "Malawi", "Mali", "Mauritanie", "Maurice", "Maroc", "Mozambique", "Namibie",
    "Niger", "Nigéria", "Rwanda", "Sao Tomé-et-Principe", "Sénégal", "Seychelles", "Sierra Leone",
    "Somalie", "Afrique du Sud", "Soudan du Sud", "Soudan", "Tanzanie", "Togo", "Tunisie",
    "Ouganda", "Zambie", "Zimbabwe"
]

produits = ["maïs", "riz", "blé", "niébé", "sorgho", "soja", "cajou", "karité", "arachide", "mil", "tubercules"]

mois_francais = {
    'janvier': '01', 'février': '02', 'fevrier': '02', 'mars': '03',
    'avril': '04', 'mai': '05', 'juin': '06',
    'juillet': '07', 'août': '08', 'aout': '08', 'septembre': '09',
    'octobre': '10', 'novembre': '11', 'décembre': '12', 'decembre': '12'
}

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed


base_url = 'https://www.agenceecofin.com/actualites-agro'
data = []
article_tasks = []

def normalize(text):
    return text.lower().strip()


def match_country(title, countries):
    for country in countries:
        if re.search(rf'\b{re.escape(country.lower())}\b', title.lower()):
            return country
    return None

# === ÉTAPE 1 : COLLECTE DES LIENS ===
for page in tqdm(range(0, 5120, 10), desc="Collecte des liens"):  # Augmentez si nécessaire
    try:
        url = f'{base_url}?limitstart={page}'
        response = requests.get(url, timeout=20)
        soup = BeautifulSoup(response.text, 'lxml')
        articles = soup.find_all('div', class_='catItemHeader')

        for article in articles:
            title_tag = article.find('div', class_='catItemTitle')
            if not title_tag:
                continue
            title = title_tag.text.strip()
            country = match_country(title, countries)
            if country:
                href = article.a['href']
                full_url = f'https://www.agenceecofin.com{href}'
                article_tasks.append((title, full_url, country))
    except Exception as e:
        print(f"[Erreur page {page}] {e}")
        continue

print(f"Total articles trouvés : {len(article_tasks)}")

# === ÉTAPE 2 : TRAITEMENT PARALLÈLE DES ARTICLES ===
def process_article(title, url_article, country):
    try:
        html = requests.get(url_article, timeout=20).text
        soup = BeautifulSoup(html, 'lxml')
        text_parts = soup.find_all('div', class_='itemIntroText')
        texte_complet = " ".join(normalize(p.text) for p in text_parts)
        texte_final = re.split(r"lire\\s+aussi[:\\s]*", texte_complet, flags=re.IGNORECASE)[0].strip()
        texte_final = re.sub(r"\bmillions?\b|\bmilliards?\b|\bmilliers?\b|\bmilieu?\b", "", texte_final)
        texte_final = re.sub(r"\s{2,}", " ", texte_final).strip()

        # Date
        date_tag = soup.find('span', class_='itemDateCreated')
        if date_tag:
            match = re.search(r'(\d{1,2})\s+(\w+)\s+(\d{4})', date_tag.text.lower())
            if match:
                mois_nom, annee = match.group(2), match.group(3)
                mois_num = mois_francais.get(mois_nom)
                published_date = f"{mois_num}-{annee}" if mois_num else "Date inconnue"
            else:
                published_date = "Date inconnue"
        else:
            published_date = "Date inconnue"

        # Produits et action détectée
        produits_trouves = [p for p in produits if normalize(p) in texte_final]
        action_keywords = ["interdiction", "embargo", "suspension", "restriction", "plafonnement", "blocage", "régulation"]
        action_detectee = any(kw in texte_final for kw in action_keywords)

        return {
            "pays": country,
            "title": title,
            "date": published_date,
            "article": texte_final,
            "produits": ", ".join(set(produits_trouves)),
            "action_detectee": action_detectee
        }

    except Exception as e:
        print(f"[Erreur article] {url_article} : {e}")
        return None

# Exécution multithread
with ThreadPoolExecutor(max_workers=8) as executor:
    futures = [executor.submit(process_article, t, u, c) for t, u, c in article_tasks]
    for future in tqdm(as_completed(futures), total=len(futures), desc="Traitement articles"):
        result = future.result()
        if result:
            data.append(result)
# Out:
# Collecte des liens: 100%|████████████████████████████████████████████████████████████| 512/512 [15:20<00:00,  1.80s/it]
# Total articles trouvés : 3014
# Traitement articles:  15%|████████▏                                               | 443/3014 [02:36<1:17:56,  1.82s/it]
# [Erreur article] https://www.agenceecofin.com/intrants/1307-110235-cameroun-yara-international-cede-la-totalite-des-actions-de-sa-filiale-locale-au-groupe-njs : HTTPSConnectionPool(host='www.agenceecofin.com', port=443): Read timed out. (read timeout=20)
# [Erreur article] https://www.agenceecofin.com/agrobusiness/1207-110217-angola-une-joint-venture-emiratie-veut-developper-plus-de-3-700-hectares-de-terres-agricoles : HTTPSConnectionPool(host='www.agenceecofin.com', port=443): Read timed out. (read timeout=20)
# Traitement articles:  15%|████████▏                                               | 444/3014 [02:37<1:01:20,  1.43s/it]
# ...

# %%
# Conversion en DataFrame et aperçu
df = pd.DataFrame(data)
df.head()
# Out:
#       pays                                              title     date  \
# 0  Nigéria  Le Nigéria se dote d’un groupe de travail pour...  10-2024
# 1  Namibie  Namibie : AB InBev veut injecter 3,4 millions ...  10-2024
# 2    Ghana  Hausse de 35 % du chiffre d’affaires de Guinne...  10-2024
# 3   Rwanda  Le Rwanda veut augmenter sa production de vian...  10-2024
# 4     Togo  Le Togo prépare un plan à 36,7 millions $ pour...  10-2024
#
#                                              article produits  action_detectee
# 0  (agence ecofin) - le nigéria est le 3ème produ...     soja            False
# 1  (agence ecofin) - en afrique australe, la nami...                     False
# 2  (agence ecofin) - en afrique de l’ouest, le gh...                     False
# 3  (agence ecofin) - au rwanda, l’élevage contrib...                     False
# 4  (agence ecofin) - les exportations togolaises ...      riz            False

# %%
df.tail()
# Out:
#             pays                                              title     date  \
# 2998     Burundi  Un milliard de $ pour le Plan national d'inves...  03-2012
# 2999       Ghana  Les brasseries du Ghana misent sur une bière t...  03-2012
# 3000       Niger  Le chinois Sinolight envisage la construction ...  03-2012
# 3001  Mozambique  Prochain angle d’attaque d’Agriterra : les bou...  03-2012
# 3002  Mozambique  Le portugais Sumol se lance dans les jus au Mo...  02-2012
#
#                                                 article           produits  \
# 2998  (agence ecofin) - une quinzaine des bailleurs ...
# 2999  (agence ecofin) - la nouvelle usine d’accra br...  sorgho, maïs, mil
# 3000  à l’issue d’un entretien avec le président du ...
# 3001  (agence ecofin) - agriterra, la société britan...               maïs
# 3002  (agence ecofin) - le portugais sumol devrait d...
#
#       action_detectee
# 2998            False
# 2999            False
# 3000            False
# ...

# %%
# Export en Excel
df.to_excel("articles_ecofin_All.xlsx", index=False)

# %%
# Articles où une action (interdiction, embargo, etc.) est détectée
df_action = df[df["action_detectee"] == True]

# Affichage d’un aperçu
print(f"{len(df_action)} articles avec action détectée sur {len(df)} au total.")
df_action.head()
# Out:
# 223 articles avec action détectée sur 3003 au total.
#             pays                                              title     date  \
# 17  Burkina Faso  Burkina Faso : interdiction d’importation de f...  09-2024
# 25         Ghana  Ghana : l’exploitation minière illégale inquiè...  09-2024
# 28  Burkina Faso  Burkina Faso : le gouvernement suspend l’expor...  09-2024
# 54      Tanzanie  Utilisation d’engrais : la Tanzanie cible le m...  08-2024
# 55         Ghana  Sécheresse au Ghana : le gouvernement interdit...  08-2024
#
#                                               article  \
# 17  (agence ecofin) - le burkina faso fait partie ...
# 25  (agence ecofin) - au ghana, l’exploitation min...
# 28  (agence ecofin) - au burkina faso, la producti...
# 54  (agence ecofin) - la tanzanie affiche l’un des...
# 55  (agence ecofin) - au ghana comme dans la major...
#
#                                   produits  action_detectee année
# ...

# %% [markdown]
# ## 📊 Visualisation des données collectées
#
# Voyons maintenant quelques statistiques de base sur les articles collectés :

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

# Configuration de style
sns.set(style="whitegrid")

# %% [markdown]
# ### Nombre d'articles par pays

# %%
plt.figure(figsize=(12,6))
article_counts = df_action['pays'].value_counts().sort_values(ascending=False)
sns.barplot(x=article_counts.values, y=article_counts.index, palette="viridis")
plt.title("Nombre d'articles par pays")
plt.xlabel("Nombre d'articles")
plt.ylabel("Pays")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Répartition des produits agricoles mentionnés

# %%
from collections import Counter
produit_list = ",".join(df_action['produits'].dropna()).split(", ")
produit_counts = Counter(produit_list)
produit_df = pd.DataFrame.from_dict(produit_counts, orient='index', columns=['count'])
produit_df = produit_df.sort_values(by='count', ascending=False)

plt.figure(figsize=(12,6))
sns.barplot(x=produit_df['count'], y=produit_df.index, palette="mako")
plt.title("Fréquence des produits agricoles mentionnés")
plt.xlabel("Occurrences")
plt.ylabel("Produits agricoles")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Nombre d'articles par année

# %%
# Extraire l'année de la colonne 'date' au format MM-YYYY
df_action['année'] = df_action['date'].apply(lambda x: x.split('-')[1] if '-' in x else None)
year_counts = df_action['année'].value_counts().sort_index()

plt.figure(figsize=(8,5))
sns.barplot(x=year_counts.index, y=year_counts.values, palette="crest")
plt.title("Nombre d'articles par année")
plt.xlabel("Année")
plt.ylabel("Nombre d'articles")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\AHema\AppData\Local\Temp\ipykernel_27588\1101339713.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_action['année'] = df_action['date'].apply(lambda x: x.split('-')[1] if '-' in x else None)
